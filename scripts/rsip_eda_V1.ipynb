# %% [markdown]
# <a href="https://colab.research.google.com/github/GreenVaultJoe/capstone_project/blob/main/scripts/rsip_eda_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("initial script created!")
# Out:
# initial script created!

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.listdir("capstone_project/data/raw_data")
# Out:
# ['README.txt',
#  'Residential_Solar_Investment_Program_(RSIP)_Enrollment_20251119.csv']

# %%
file_path = "capstone_project/data/raw_data/Residential_Solar_Investment_Program_(RSIP)_Enrollment_20251119.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#   Entity Incentive Type Sub Program            Approved Date  \
# 0    CGB           EPBB        EPBB  2012 Mar 05 12:00:00 AM
# 1    CGB           EPBB        EPBB  2012 Mar 06 12:00:00 AM
# 2    CGB           EPBB        EPBB  2012 Mar 06 12:00:00 AM
# 3    CGB           EPBB        EPBB  2012 Mar 07 12:00:00 AM
# 4    CGB           EPBB        EPBB  2012 Mar 07 12:00:00 AM
#
#             Completed Date  kW STC Incentive Amount Total System Cost  \
# 0  2012 May 27 12:00:00 AM    6.00           10,855            33,300
# 1  2012 Aug 09 12:00:00 AM    5.40           10,722            35,383
# 2  2013 Feb 20 12:00:00 AM    6.00           12,507            30,000
# 3  2012 Jun 27 12:00:00 AM    4.75            9,265            23,987
# 4  2012 Jul 25 12:00:00 AM    9.31           15,457            41,071
#
#   Expected Annual Generation (kWh)              Contractor  ...  \
# 0                          6,832.8     BeFree Green Energy  ...
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48354 entries, 0 to 48353
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Entity                            48354 non-null  object
#  1   Incentive Type                    48354 non-null  object
#  2   Sub Program                       48354 non-null  object
#  3   Approved Date                     48354 non-null  object
#  4   Completed Date                    48354 non-null  object
#  5   kW STC                            48354 non-null  float64
#  6   Incentive Amount                  48354 non-null  object
#  7   Total System Cost                 48354 non-null  object
#  8   Expected Annual Generation (kWh)  48354 non-null  object
#  9   Contractor                        48354 non-null  object
#  10  System Owner                      48354 non-null  object
# ...
